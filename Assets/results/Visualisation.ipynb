# %%
import matplotlib.pyplot as plt
import pandas as pd

if __name__ == '__main__':
    plt.rcParams["font.family"] = "Times New Roman"
    plt.rcParams['axes.labelsize'] = 21

    basePath = "C:/Users/bowro/AppData/LocalLow/AManu/Hell AR World"
    path1 = basePath + "/BasicGeneticImplResults_Ps6_Cl5_Pd5.2.5_G5.txt"
#     path2 = basePath + "/BasicGeneticImplResults_Ps20_Cl20_Pd20_G25.txt"
#     path3 = basePath + "/BasicGeneticImplResults_Ps50_Cl50_Pd50_G25.txt"

    column_header = ["Chromosome id", "Generation Time (ms)","Fitness", "Generation"]
    
#     #10,10,10
    df = pd.read_csv(path1, header = None, names=column_header)    
    # title="Generation vs Generation Time",
    fig1 = df.boxplot(column=['Generation Time (ms)'], by='Generation', figsize=(15,10))
    plt.title("")
    plt.suptitle("")
    fig1.set_ylabel('Generation Time (ms)')
    fig1.set_xlabel('Generation')
    # title="Generation Time vs Fitness",
    fig2 = df.plot.scatter(x=column_header[1], y=column_header[2], figsize=(15,10)).get_figure()
    print(df.mean())
    print(df.std())
    
#     #20,20,20
#     df2 = pd.read_csv(path2, header = None, names=column_header)    
#     # title="Generation vs Generation Time",
#     fig1 = df2.boxplot(column=['Generation Time (ms)'], by='Generation', figsize=(15,10))
#     plt.title("")
#     plt.suptitle("")
#     fig1.set_ylabel('Generation Time (ms)')
#     fig1.set_xlabel('Generation')
#     # title="Generation Time vs Fitness",
#     fig2 = df2.plot.scatter(x=column_header[1], y=column_header[2], figsize=(15,10)).get_figure()
#     print(df2.mean())
#     print(df2.std())

#     #50,50,50
#     df3 = pd.read_csv(path3, header = None, names=column_header)    
#     # title="Generation vs Generation Time",
#     fig1 = df3.boxplot(column=['Generation Time (ms)'], by='Generation', figsize=(15,10))
#     plt.title("")
#     plt.suptitle("")
#     fig1.set_ylabel('Generation Time (ms)')
#     fig1.set_xlabel('Generation')
#     # title="Generation Time vs Fitness",
#     fig2 = df3.plot.scatter(x=column_header[1], y=column_header[2], figsize=(15,10)).get_figure()
#     print(df3.mean())
#     print(df3.std())
    
    plt.show(block=True)
#     fig1.savefig('./Graphs/GenerationVsGenerationTime.png')
#     fig2.savefig('./Graphs/GenerationTimeVsFitness.png')
# Out:
# Chromosome id           81.566667
# Generation Time (ms)    12.613373
# Fitness                  0.120981
# Generation               3.000000
# dtype: float64
# Chromosome id           22.234777
# Generation Time (ms)     5.304283
# Fitness                  0.006714
# Generation               1.426148
# dtype: float64
